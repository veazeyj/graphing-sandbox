# %%
import matplotlib.pyplot as plt
import numpy as np  

# Use Times New Roman globally
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.rm'] = 'Times New Roman'
plt.rcParams['mathtext.it'] = 'Times New Roman:italic'

label_font = 20
tick_font = 20

### if using for kinematics, some parameters set below ###
x0 = 0
v0 = 0
a = -0.24

# Use these for blank axes
#t = []
#x = []

########Use the following if you'd like to add a plot: the first two arrays are for functions, the second two are for discrete points.########
#t = np.linspace(0, 5, 100)
#x = x0+v0*t+0.5*a*t**2
x = [0, 1, 1, 3]
y = [10, 10, -5, 0]

# Create the plot with these if there is a DISCONTINUITY in the function.
#t1 = [0, 1]
#x1 = [10, 10]
#t2 = [1, 3]
#x2 = [-5, 0]

# Create the plot
fig, ax = plt.subplots(figsize=(6, 4))
#ax.plot(t_blank, x_blank, color='blue', linewidth=4)
line1, = ax.plot(x, y, color='blue', linewidth=4, linestyle='-')
line1.set_visible(True)  # Hide the line

# Create the plot with these if there is a DISCONTINUITY in the function.
#ax.plot(t1, x1, color='blue', linewidth=4, linestyle='-')
#ax.plot(t2, x2, color='blue', linewidth=4, linestyle='-')
#ax.plot([1, 1], [-5, 10], color='black', linewidth=1, linestyle=':')

x_min=np.min(x)
x_max=np.max(x)
y_min=np.min(y)
y_max=np.max(y)
# Axis limits
#ax.set_xlim(x_min, x_max)
ax.set_ylim(-10, )

# Axis limits
#ax.set_xlim(0, 5)
#ax.set_ylim(-3, 3)

# Ticks
#ax.set_xticks([1, 2, 3, 4])
#ax.set_yticks([-3, -2, -1, 0, 1, 2, 3])
# Alternate Ticks (comment out two rows above)
#ax.set_xticks([])
#ax.set_yticks([])


# Grid on major + minor ticks
ax.grid(True, which='major', linestyle='--', linewidth=0.8, alpha=0.6)
##ax.grid(True, which='minor', linestyle=':', linewidth=0.6, alpha=0.4)


# Move spines so axes cross at (0,0)
ax.spines['left'].set_position('zero')   # y-axis at t = 0
ax.spines['bottom'].set_position('zero') # x-axis at x = 0

# Hide top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add axis labels at the ends
ax.text(x_max+x_max/10, 0.0, r'$\it{x}\ (\mathrm{m})$', fontsize=label_font, fontname='Times New Roman')
#ax.text(-0.4, 4, r'$\it{x}\ (\mathrm{m})$', fontsize=label_font)
ax.text(-1*x_max/10, y_max+y_max/5, r'$\it{\vec{F}_{\text{app}}}\ (\mathrm{N})$', fontsize=label_font)
#ax.text(-0.4, 4, r'$\it{a}\ (\mathrm{m/s^2})$', fontsize=label_font)
#ax.text(-0.4, 540, r'$\it{F_{floor\rightarrow ball}}\ (\mathrm{N})$', fontsize=label_font)

ax.tick_params(axis='both', which='major', labelsize=tick_font, labelbottom=True, labelleft=True)  # major ticks
#ax.tick_params(axis='both', which='minor', labelsize=tick_font-2)  # minor ticks
ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%.1f'))
#ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.1f'))

# Double-headed arrow from t=1 to t=3, below the x-axis
#ax.annotate('', xy=(3, -60), xytext=(1, -60),
 #           arrowprops=dict(arrowstyle='<->', color='black', lw=1.5),
  #          annotation_clip=False)

# Label centered below the arrow
#ax.text(2, -100, '10 ms', fontsize=label_font - 2,
 #       ha='center', va='top', fontname='Times New Roman')


plt.show()
